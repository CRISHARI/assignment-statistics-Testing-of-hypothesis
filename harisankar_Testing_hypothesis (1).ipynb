# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
data=pd.read_csv('Sales_add.csv')
data.head()
# Out:
#      Month      Region      Manager  Sales_before_digital_add(in $)  \
# 0  Month-1  Region - A  Manager - A                          132921
# 1  Month-2  Region - A  Manager - C                          149559
# 2  Month-3  Region - B  Manager - A                          146278
# 3  Month-4  Region - B  Manager - B                          152167
# 4  Month-5  Region - C  Manager - B                          159525
#
#    Sales_After_digital_add(in $)
# 0                         270390
# 1                         223334
# 2                         244243
# 3                         231808
# 4                         258402

# %%
x=data['Sales_before_digital_add(in $)']
x
# Out:
# 0     132921
# 1     149559
# 2     146278
# 3     152167
# 4     159525
# 5     137163
# 6     130625
# 7     131140
# 8     171259
# 9     141956
# 10    159339
# 11    178939
# 12    145062
# 13    151514
# 14    147463
# 15    177195
# 16    140862
# 17    167996
# 18    132135
# 19    152493
# 20    147425
# 21    130263
# Name: Sales_before_digital_add(in $), dtype: int64

# %%
y=data['Sales_After_digital_add(in $)']
y
# Out:
# 0     270390
# 1     223334
# 2     244243
# 3     231808
# 4     258402
# 5     256948
# 6     222106
# 7     230637
# 8     226261
# 9     193735
# 10    203175
# 11    276279
# 12    205180
# 13    253131
# 14    229336
# 15    187305
# 16    234908
# 17    191517
# 18    227040
# 19    212579
# 20    263388
# 21    243020
# Name: Sales_After_digital_add(in $), dtype: int64

# %%
data.drop('Month',axis=1,inplace=True)
data.head()
# Out:
#        Region      Manager  Sales_before_digital_add(in $)  \
# 0  Region - A  Manager - A                          132921
# 1  Region - A  Manager - C                          149559
# 2  Region - B  Manager - A                          146278
# 3  Region - B  Manager - B                          152167
# 4  Region - C  Manager - B                          159525
#
#    Sales_After_digital_add(in $)
# 0                         270390
# 1                         223334
# 2                         244243
# 3                         231808
# 4                         258402

# %%
data.drop('Region',axis=1,inplace=True)
data.head()
# Out:
#        Manager  Sales_before_digital_add(in $)  Sales_After_digital_add(in $)
# 0  Manager - A                          132921                         270390
# 1  Manager - C                          149559                         223334
# 2  Manager - A                          146278                         244243
# 3  Manager - B                          152167                         231808
# 4  Manager - B                          159525                         258402

# %%
data.drop('Manager',axis=1,inplace=True)
data.head()
# Out:
#    Sales_before_digital_add(in $)  Sales_After_digital_add(in $)
# 0                          132921                         270390
# 1                          149559                         223334
# 2                          146278                         244243
# 3                          152167                         231808
# 4                          159525                         258402

# %%
data['Sales_before_digital_add(in $)'].mean()
# Out:
# 149239.95454545456

# %%
data['Sales_After_digital_add(in $)'].mean()
# Out:
# 231123.72727272726

# %%
from statsmodels.stats.weightstats import ztest


data1=('Sales_before_digital_add(in $)')
data2=('Sales_After_digital_add(in $)')


import pandas as pd
data=pd.read_csv('Sales_add.csv')
dataz_stat,p_val=ztest(data['Sales_before_digital_add(in $)'],data['Sales_After_digital_add(in $)'],value=0)
p_val

1.3046367348248653e-38

if p_val<0.05:
  print('Null Hypothesis is Rejected')
else:
  print('Null Hypothesis is Accepted')
# Out:
# Null Hypothesis is Rejected

# %% [markdown]
# ##2.The company needs to check whether there is any dependency between the features “Region” and “Manager”.H0: The variables has no relationship HA:There is a significant link between the two

# %%
from scipy.stats import chi2_contingency


tab_data=[130263,187305]


chi2_contingency(tab_data)



chi2_stat,p_value,dof,exp=chi2_contingency(tab_data)
p_value
# Out:
# 1.0

# %%
import scipy.stats as stats
from statsmodels.stats.weightstats import ztest
data1=data['Sales_After_digital_add(in $)']
mean=231123
n=len(data1)
alpha=0.05
z_val,p_val=ztest(data1,value=mean)
if p_val<alpha:
   print('Reject null hypothesis')
else:
    print('do not reject null hypothesis')
# Out:
# do not reject null hypothesis

# %%
data1.head()
# Out:
# 0    270390
# 1    223334
# 2    244243
# 3    231808
# 4    258402
# Name: Sales_After_digital_add(in $), dtype: int64

# %%
p_val
# Out:
# 0.9998935017140722

# %%
import scipy.stats as stats
from statsmodels.stats.weightstats import ztest
data2=data['Sales_before_digital_add(in $)']
mean=149239
n=len(data2)
alpha=0.05
z_val,p_val=ztest(data2,value=mean)
if p_val<alpha:
   print('Reject null hypothesis')
else:
    print('do not reject null hypothesis')
# Out:
# do not reject null hypothesis

# %%
data2.head()
# Out:
# 0    132921
# 1    149559
# 2    146278
# 3    152167
# 4    159525
# Name: Sales_before_digital_add(in $), dtype: int64

# %%
p_val
# Out:
# 0.9997593444910182

# %%
import numpy as np
from scipy import stats
data1=data['Sales_After_digital_add(in $)']
mean=231123
t_val,p_val=stats.ttest_1samp(data1,mean)
alpha=0.05
if p_val<alpha:
   print('Reject null hypothesis')
else:
    print('do not reject null hypothesis')
# Out:
# do not reject null hypothesis

# %%
import numpy as np
from scipy import stats
data2=data['Sales_After_digital_add(in $)']
mean=149239
t_val,p_val=stats.ttest_1samp(data2,mean)
alpha=0.05
if p_val<alpha:
   print('Reject null hypothesis')
else:
    print('do not reject null hypothesis')
# Out:
# Reject null hypothesis
